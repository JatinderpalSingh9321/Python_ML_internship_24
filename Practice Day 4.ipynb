# %%
import numpy as np

# %%
ar1=np.array([[85,90,78],[92,88,95],[76,95,85],[90,85,92],[88,76,89]])

# %%
ar1
# Out:
# array([[85, 90, 78],
#        [92, 88, 95],
#        [76, 95, 85],
#        [90, 85, 92],
#        [88, 76, 89]])

# %%
ar2=np.mean(ar1, axis=1)

# %%
ar2
# Out:
# array([84.33333333, 91.66666667, 85.33333333, 89.        , 84.33333333])

# %%
np.median(ar1, axis=0)
# Out:
# array([88., 88., 89.])

# %%
np.max(ar2)
# Out:
# 91.66666666666667

# %%
# Out:
# 1

# %%
np.max(ar1, axis=0)
# Out:
# array([92, 95, 95])

# %%
np.min(ar1, axis=0)
# Out:
# array([76, 76, 78])

# %%
np.reshape(ar1, (3,5))
# Out:
# array([[85, 90, 78, 92, 88],
#        [95, 76, 95, 85, 90],
#        [85, 92, 88, 76, 89]])

# %%
np.sort(ar1, axis=0)
# Out:
# array([[76, 76, 78],
#        [85, 85, 85],
#        [88, 88, 89],
#        [90, 90, 92],
#        [92, 95, 95]])

# %%
sum=np.sum(ar1, axis=1)
print(max(sum))
index=np.argmax(sum)
high=ar1[index]
print(high)
# Out:
# 275
# [92 88 95]
