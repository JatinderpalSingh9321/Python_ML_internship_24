# %% [markdown]
# # **Data on Diabetes**

# %% [markdown]
# # Table of Contents
# - [Importing](#Importing)
# - [Data Loading](#Data-Loading)
# - [Testing and Training](#Testing-and-Training)
# - [Data Visualization](#Data-Visualization)

# %% [markdown]
# # [Importing](#Importing)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import accuracy_score,confusion_matrix,recall_score,precision_score

# %% [markdown]
# # [Data Loading](#data-loading)

# %%
Diabetes=pd.read_csv("diabetes.csv")
Diabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
Diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
Diabetes.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
Diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# # [Testing and Training](#Testing-and-Training)

# %%
X=Diabetes.drop(columns=['Outcome'])
Y=Diabetes['Outcome']

# %%
Y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
X_train,X_test,Y_train,Y_test =train_test_split(X,Y,test_size=0.40,random_state=0)

# %%
model = LogisticRegression(max_iter=1000)
model.fit(X_train,Y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
Y_pred=model.predict(X_test)

# %%
DF_test_predict= X_test
DF_test_predict["Y_test"]=Y_test
DF_test_predict["Y_pred"]=Y_pred
DF_test_predict
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 661            1      199             76             43        0  42.9
# 122            2      107             74             30      100  33.6
# 113            4       76             62              0        0  34.0
# 14             5      166             72             19      175  25.8
# 529            0      111             65              0        0  24.6
# ..           ...      ...            ...            ...      ...   ...
# 407            0      101             62              0        0  21.9
# 179            5      130             82              0        0  39.1
# 0              6      148             72             35        0  33.6
# 46             1      146             56              0        0  29.7
# 171            6      134             70             23      130  35.4
#
#      DiabetesPedigreeFunction  Age  Y_test  Y_pred
# 661                     1.394   22       1       1
# ...

# %%
CM=confusion_matrix(Y_test,Y_pred)
AS=accuracy_score(Y_test,Y_pred)
RS=recall_score(Y_test,Y_pred)
PS=precision_score(Y_test,Y_pred)
print(f"Accuracy Score= {AS}\nRecall Score= {RS}\nPrecision Score={PS}\nConfusion Matrix={CM}")
# Out:
# Accuracy Score= 0.788961038961039
# Recall Score= 0.5339805825242718
# Precision Score=0.7638888888888888
# Confusion Matrix=[[188  17]
#  [ 48  55]]

# %% [markdown]
# # [Data Visualization](#data-visualization)

# %%
#Scatter Graph
sns.scatterplot(y='Glucose', x='Insulin', hue='Outcome', data=Diabetes, palette=['green','red'])
plt.title('Glucose vs BMI by Outcome')
plt.show()

# %%
PregVSOut=Diabetes.groupby(["Pregnancies","Outcome"]).size().unstack(fill_value=0)
PregVSOut
# Out:
# Outcome        0   1
# Pregnancies
# 0             73  38
# 1            106  29
# 2             84  19
# 3             48  27
# 4             45  23
# 5             36  21
# 6             34  16
# 7             20  25
# 8             16  22
# 9             10  18
# 10            14  10
# 11             4   7
# 12             5   4
# 13             5   5
# 14             0   2
# 15             0   1
# 17             0   1

# %%
# Bar Graph
PregVSOut.plot(kind='bar')
plt.show()

# %%
# Pie chart
plt.figure(figsize=(10,6))
labels = ['Diabetic', 'Non-Diabetic']
colors = ['#ff9999', '#66b3ff'] 
df=Diabetes['Outcome'].value_counts()
plt.pie(df, labels=labels, colors=colors, autopct='%.2f%%', startangle=140)
plt.title('Diabetic vs Non-Diabetic Population')
plt.show()

# %%
#Histograph
Diabetes.hist(figsize=(10,9))
plt.suptitle("HISTOGRAPHS")
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.heatmap(CM,annot=True,fmt='d',cmap='Blues',xticklabels=["Non-Dibetic","Diabetic"],yticklabels=["Non-Dibetic","Diabetic"])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
corr_matrix = Diabetes.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
