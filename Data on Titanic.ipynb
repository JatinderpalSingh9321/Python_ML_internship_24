# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import os
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ti = pd.read_csv("/content/drive/MyDrive/titanic.csv")
ti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#Graph of sex of people
mVSf=ti.groupby(["survived","sex"]).size().unstack(fill_value=0)
mVSf
# Out:
# sex       female  male
# survived
# 0             81   468
# 1            233   109

# %%
mVSf.plot(kind="bar",color=['pink','blue'])
plt.ylabel("Survived")
plt.xlabel("Sex")
plt.grid()
plt.show()

# %%
#Graph of Alive or dead people
dt=ti.groupby(["who","alive"]).size().unstack(fill_value=0)
dt
# Out:
# alive   no  yes
# who
# child   34   49
# man    449   88
# woman   66  205

# %%
dt.plot(kind="bar", color=['r','g'])
plt.ylabel("Alive")
plt.xlabel("Sex")
plt.grid()
plt.show()

# %%
#Graph of address of people
Address=ti.groupby(["sex","embark_town"]).size().unstack(fill_value=0)
Address
# Out:
# embark_town  Cherbourg  Queenstown  Southampton
# sex
# female              73          36          203
# male                95          41          441

# %%
Address.plot(kind="bar")
plt.ylabel("sex")
plt.xlabel("embark_town")
plt.grid()
plt.show()

# %%
#Graph of people who are alone
family=ti.groupby(["alone","who"]).size().unstack(fill_value=0)
family
# Out:
# who    child  man  woman
# alone
# False     77  127    150
# True       6  410    121

# %%
family.plot(kind="bar")
plt.grid()
plt.show()

# %%
dw=ti.groupby(["deck","who"]).size().unstack(fill_value=0)
dw
# Out:
# who   child  man  woman
# deck
# A         1   13      1
# B         3   19     25
# C         2   31     26
# D         0   15     18
# E         1   16     15
# F         4    5      4
# G         2    0      2

# %%
dw.plot(kind="bar")
plt.grid()
plt.show()

# %%
cw=ti.groupby(["class","who"]).size().unstack(fill_value=0)
cw
# Out:
# who     child  man  woman
# class
# First       6  119     91
# Second     19   99     66
# Third      58  319    114

# %%
cw.plot(kind="bar")
plt.grid()
plt.show()
