# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Pandas**
#
# -Pandas are used in data cleaning and managing, it also deals with import, export and manipulation of the data.
#
# series: 1D array
#
# dataframe: 2D array(or higher dimensional array)

# %%
dic={
    "Name":["Ram","Shyam","Sameer","Kajal","Irfan","Rohit"],
    "Roll no":[1,2,3,4,5,6],
    "Grades":["A","B","C","C","B","A"],
    "Email":["abc@gmail.com","def@gmail.com","ghi@gmail.com","jkl@gmail.com","mno@gmail.com","pqr@gmail.com"]
}

# %%
dic
# Out:
# {'Name': ['Ram', 'Shyam', 'Sameer', 'Kajal', 'Irfan', 'Rohit'],
#  'Roll no': [1, 2, 3, 4, 5, 6],
#  'Grades': ['A', 'B', 'C', 'C', 'B', 'A'],
#  'Email': ['abc@gmail.com',
#   'def@gmail.com',
#   'ghi@gmail.com',
#   'jkl@gmail.com',
#   'mno@gmail.com',
#   'pqr@gmail.com']}

# %%
df = pd.DataFrame(dic)

# %%
df
# Out:
#      Name  Roll no Grades          Email
# 0     Ram        1      A  abc@gmail.com
# 1   Shyam        2      B  def@gmail.com
# 2  Sameer        3      C  ghi@gmail.com
# 3   Kajal        4      C  jkl@gmail.com
# 4   Irfan        5      B  mno@gmail.com
# 5   Rohit        6      A  pqr@gmail.com

# %%
pd.Series(dic)
# Out:
# Name               [Ram, Shyam, Sameer, Kajal, Irfan, Rohit]
# Roll no                                   [1, 2, 3, 4, 5, 6]
# Grades                                    [A, B, C, C, B, A]
# Email      [abc@gmail.com, def@gmail.com, ghi@gmail.com, ...
# dtype: object

# %%
df.head()
# Out:
#      Name  Roll no Grades          Email
# 0     Ram        1      A  abc@gmail.com
# 1   Shyam        2      B  def@gmail.com
# 2  Sameer        3      C  ghi@gmail.com
# 3   Kajal        4      C  jkl@gmail.com
# 4   Irfan        5      B  mno@gmail.com

# %%
df.tail()
# Out:
#      Name  Roll no Grades          Email
# 1   Shyam        2      B  def@gmail.com
# 2  Sameer        3      C  ghi@gmail.com
# 3   Kajal        4      C  jkl@gmail.com
# 4   Irfan        5      B  mno@gmail.com
# 5   Rohit        6      A  pqr@gmail.com

# %%
df.head(2)
# Out:
#     Name  Roll no Grades          Email
# 0    Ram        1      A  abc@gmail.com
# 1  Shyam        2      B  def@gmail.com

# %%
df.tail(2)
# Out:
#     Name  Roll no Grades          Email
# 4  Irfan        5      B  mno@gmail.com
# 5  Rohit        6      A  pqr@gmail.com

# %%
df.describe()
# Out:
#         Roll no
# count  6.000000
# mean   3.500000
# std    1.870829
# min    1.000000
# 25%    2.250000
# 50%    3.500000
# 75%    4.750000
# max    6.000000

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cus = pd.read_csv("/content/drive/My Drive/Customer.csv")

# %%
cus
# Out:
#     CustomerID                        Company Name       Costumer Name  \
# 0            1                 Alfreds Futterkiste        Maria Anders
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taqueria      Antonio Moreno
# 3            4                     Around the Horn        Thomas Hardy
# 4            5                   Berglunds snabbkp  Christina Berglund
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#            City  PostalCode  Country
# 0        Berlin       12209  Germany
# 1   Mexico D.F.        5021   Mexico
# ...

# %%
type(cus)
# Out:
# pandas.core.frame.DataFrame

# %%
type(cus['CustomerID'])
# Out:
# pandas.core.series.Series

# %%
cus.index
# Out:
# RangeIndex(start=0, stop=91, step=1)

# %%
cus.columns
# Out:
# Index(['CustomerID', 'Company Name', 'Costumer Name', 'City', 'PostalCode',
#        'Country'],
#       dtype='object')

# %%
cus.to_numpy()
# Out:
# array([[1, 'Alfreds Futterkiste', 'Maria Anders', 'Berlin', 12209,
#         'Germany'],
#        [2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo',
#         'Mexico D.F.', 5021, 'Mexico'],
#        [3, 'Antonio Moreno Taqueria', 'Antonio Moreno', 'Mexico D.F.',
#         5023, 'Mexico'],
#        [4, 'Around the Horn', 'Thomas Hardy', 'London', 34626, 'UK'],
#        [5, 'Berglunds snabbkp', 'Christina Berglund', 'Lulea', 95822,
#         'Sweden'],
#        [6, 'Blauer See Delikatessen', 'Hanna Moos', 'Mannheim', 68306,
#         'Germany'],
#        [7, 'Blondel pere et fils', 'Frederique Citeaux', 'Strasbourg',
#         67000, 'France'],
#        [8, 'BOlido Comidas preparadas', 'Martin Sommer', 'Madrid', 28023,
#         'Spain'],
#        [9, 'Bon app', 'Laurence Lebihans', 'Marseille', 13008, 'France'],
#        [10, 'Bottom-Dollar Marketse', 'Elizabeth Lincoln', 'Tsawassen',
#         254685, 'Canada'],
# ...

# %%
cus.T
# Out:
#                                 0                                   1   \
# CustomerID                       1                                   2
# Company Name   Alfreds Futterkiste  Ana Trujillo Emparedados y helados
# Costumer Name         Maria Anders                        Ana Trujillo
# City                        Berlin                         Mexico D.F.
# PostalCode                   12209                                5021
# Country                    Germany                              Mexico
#
#                                     2                3                   4   \
# CustomerID                           3                4                   5
# Company Name   Antonio Moreno Taqueria  Around the Horn   Berglunds snabbkp
# Costumer Name           Antonio Moreno     Thomas Hardy  Christina Berglund
# City                       Mexico D.F.           London               Lulea
# PostalCode                        5023            34626               95822
# ...

# %%
cus.drop(0)
# Out:
#     CustomerID                        Company Name       Costumer Name  \
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taqueria      Antonio Moreno
# 3            4                     Around the Horn        Thomas Hardy
# 4            5                   Berglunds snabbkp  Christina Berglund
# 5            6             Blauer See Delikatessen          Hanna Moos
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#            City  PostalCode  Country
# 1   Mexico D.F.        5021   Mexico
# 2   Mexico D.F.        5023   Mexico
# ...

# %%
cus.drop(3)
# Out:
#     CustomerID                        Company Name       Costumer Name  \
# 0            1                 Alfreds Futterkiste        Maria Anders
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taqueria      Antonio Moreno
# 4            5                   Berglunds snabbkp  Christina Berglund
# 5            6             Blauer See Delikatessen          Hanna Moos
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#            City  PostalCode  Country
# 0        Berlin       12209  Germany
# 1   Mexico D.F.        5021   Mexico
# ...

# %%
cus.drop('Company Name', axis=1)
# Out:
#     CustomerID       Costumer Name         City  PostalCode  Country
# 0            1        Maria Anders       Berlin       12209  Germany
# 1            2        Ana Trujillo  Mexico D.F.        5021   Mexico
# 2            3      Antonio Moreno  Mexico D.F.        5023   Mexico
# 3            4        Thomas Hardy       London       34626       UK
# 4            5  Christina Berglund        Lulea       95822   Sweden
# ..         ...                 ...          ...         ...      ...
# 86          87    Pirkko Koskitalo         Oulu       90110  Finland
# 87          88       Paula Parente      Resende       51849   Brazil
# 88          89      Karl Jablonski      Seattle       98128      USA
# 89          90     Matti Karttunen     Helsinki       21240  Finland
# 90          91             Zbyszek        Walla       56189   Poland
#
# [91 rows x 5 columns]

# %%
cus.loc[(48)]
# Out:
# CustomerID                                 49
# Company Name     Magazzini Alimentari Riuniti
# Costumer Name                Giovanni Rovelli
# City                                  Bergamo
# PostalCode                              24100
# Country                                 Italy
# Name: 48, dtype: object

# %%
cus.loc[(48,78),('Company Name','Costumer Name')]
# Out:
#                     Company Name     Costumer Name
# 48  Magazzini Alimentari Riuniti  Giovanni Rovelli
# 78            Toms Spezialitaten     Karin Josephs

# %%
cus.loc[(np.arange(48,78)),('Company Name','Costumer Name')]
# Out:
#                     Company Name        Costumer Name
# 48  Magazzini Alimentari Riuniti     Giovanni Rovelli
# 49                  Maison Dewey      Catherine Dewey
# 50                Mere Paillarde       Jean Fresniere
# 51        Morgenstern Gesundkost      Alexander Feuer
# 52                   North/South       Simon Crowther
# 53        Oceano Atlantico Ltda.       Yvonne Moncada
# 54        Old World Delicatessen        Rene Phillips
# 55            Ottilies Kaseladen  Henriette Pfalzheim
# 56             Paris specialites       Marie Bertrand
# 57     Pericles Comidas clasicas  Guillermo Fernandez
# 58              Piccolo und mehr          Georg Pipps
# 59       Princesa Isabel Vinhoss     Isabel de Castro
# 60                   Que Delicia     Bernardo Batista
# 61                 Queen Cozinha       Lucia Carvalho
# 62                    QUICK-Stop          Horst Kloss
# 63                 Rancho grande     Sergio Gutierrez
# ...

# %%
cus.loc[(np.arange(48,78))]
# Out:
#     CustomerID                  Company Name        Costumer Name  \
# 48          49  Magazzini Alimentari Riuniti     Giovanni Rovelli
# 49          50                  Maison Dewey      Catherine Dewey
# 50          51                Mere Paillarde       Jean Fresniere
# 51          52        Morgenstern Gesundkost      Alexander Feuer
# 52          53                   North/South       Simon Crowther
# 53          54        Oceano Atlantico Ltda.       Yvonne Moncada
# 54          55        Old World Delicatessen        Rene Phillips
# 55          56            Ottilies Kaseladen  Henriette Pfalzheim
# 56          57             Paris specialites       Marie Bertrand
# 57          58     Pericles Comidas clasicas  Guillermo Fernandez
# 58          59              Piccolo und mehr          Georg Pipps
# 59          60       Princesa Isabel Vinhoss     Isabel de Castro
# 60          61                   Que Delicia     Bernardo Batista
# ...

# %%
cus.loc[(np.arange(48,78)),:]
# Out:
#     CustomerID                  Company Name        Costumer Name  \
# 48          49  Magazzini Alimentari Riuniti     Giovanni Rovelli
# 49          50                  Maison Dewey      Catherine Dewey
# 50          51                Mere Paillarde       Jean Fresniere
# 51          52        Morgenstern Gesundkost      Alexander Feuer
# 52          53                   North/South       Simon Crowther
# 53          54        Oceano Atlantico Ltda.       Yvonne Moncada
# 54          55        Old World Delicatessen        Rene Phillips
# 55          56            Ottilies Kaseladen  Henriette Pfalzheim
# 56          57             Paris specialites       Marie Bertrand
# 57          58     Pericles Comidas clasicas  Guillermo Fernandez
# 58          59              Piccolo und mehr          Georg Pipps
# 59          60       Princesa Isabel Vinhoss     Isabel de Castro
# 60          61                   Que Delicia     Bernardo Batista
# ...

# %%
cus.loc[:,('Company Name')]
# Out:
# 0                    Alfreds Futterkiste
# 1     Ana Trujillo Emparedados y helados
# 2                Antonio Moreno Taqueria
# 3                        Around the Horn
# 4                      Berglunds snabbkp
#                      ...
# 86                        Wartian Herkku
# 87                Wellington Importadora
# 88                  White Clover Markets
# 89                           Wilman Kala
# 90                                Wolski
# Name: Company Name, Length: 91, dtype: object

# %%
CN=cus.loc[:,('Company Name')]

# %%
CN
# Out:
# 0                    Alfreds Futterkiste
# 1     Ana Trujillo Emparedados y helados
# 2                Antonio Moreno Taqueria
# 3                        Around the Horn
# 4                      Berglunds snabbkp
#                      ...
# 86                        Wartian Herkku
# 87                Wellington Importadora
# 88                  White Clover Markets
# 89                           Wilman Kala
# 90                                Wolski
# Name: Company Name, Length: 91, dtype: object

# %%
employees = [
    {"company_name": "Tech Innovators Inc.", "employee_name": "Alice Johnson", "position": "Software Engineer"},
    {"company_name": "Tech Innovators Inc.", "employee_name": "Bob Smith", "position": "Data Scientist"},
    {"company_name": "Tech Innovators Inc.", "employee_name": "Carol White", "position": "Product Manager"},
    {"company_name": "Tech Innovators Inc.", "employee_name": "David Brown", "position": "UX Designer"},
    {"company_name": "Tech Innovators Inc.", "employee_name": "Eva Davis", "position": "Marketing Specialist"},
    {"company_name": "Global Solutions Ltd.", "employee_name": "Frank Moore", "position": "HR Manager"},
    {"company_name": "Global Solutions Ltd.", "employee_name": "Grace Lee", "position": "Sales Executive"},
    {"company_name": "Global Solutions Ltd.", "employee_name": "Hank Wilson", "position": "Financial Analyst"},
    {"company_name": "Global Solutions Ltd.", "employee_name": "Ivy Taylor", "position": "Customer Support"},
    {"company_name": "Global Solutions Ltd.", "employee_name": "Jack Harris", "position": "Systems Administrator"},
    {"company_name": "Bright Future Co.", "employee_name": "Kelly Martinez", "position": "Product Designer"},
    {"company_name": "Bright Future Co.", "employee_name": "Liam Clark", "position": "Data Analyst"},
    {"company_name": "Bright Future Co.", "employee_name": "Mia Lewis", "position": "Business Development"},
    {"company_name": "Bright Future Co.", "employee_name": "Nate Walker", "position": "Project Coordinator"},
    {"company_name": "Bright Future Co.", "employee_name": "Olivia Young", "position": "Web Developer"},
    {"company_name": "Visionary Tech LLC", "employee_name": "Paul King", "position": "Graphic Designer"},
    {"company_name": "Visionary Tech LLC", "employee_name": "Quinn Scott", "position": "Marketing Manager"},
    {"company_name": "Visionary Tech LLC", "employee_name": "Rachel Adams", "position": "Content Writer"},
    {"company_name": "Visionary Tech LLC", "employee_name": "Steve Nelson", "position": "Software Tester"},
    {"company_name": "Visionary Tech LLC", "employee_name": "Tina Baker", "position": "Product Manager"},
    {"company_name": "Pioneer Enterprises", "employee_name": "Uma Cooper", "position": "Software Developer"},
    {"company_name": "Pioneer Enterprises", "employee_name": "Vera Mitchell", "position": "IT Support Specialist"},
    {"company_name": "Pioneer Enterprises", "employee_name": "Will Robinson", "position": "Data Scientist"},
    {"company_name": "Pioneer Enterprises", "employee_name": "Xander Harris", "position": "Sales Manager"},
    {"company_name": "Pioneer Enterprises", "employee_name": "Yara Moore", "position": "Network Engineer"},
    {"company_name": "InnovateX Solutions", "employee_name": "Zane Allen", "position": "Business Analyst"},
    {"company_name": "InnovateX Solutions", "employee_name": "Amelia Carter", "position": "Customer Success Manager"},
    {"company_name": "InnovateX Solutions", "employee_name": "Ben Parker", "position": "Digital Marketer"},
    {"company_name": "InnovateX Solutions", "employee_name": "Clara Gomez", "position": "Software Tester"},
    {"company_name": "InnovateX Solutions", "employee_name": "Derek Lee", "position": "Technical Writer"},
    {"company_name": "FutureTech Dynamics", "employee_name": "Eleanor Brooks", "position": "UX Researcher"},
    {"company_name": "FutureTech Dynamics", "employee_name": "Felix Adams", "position": "Product Designer"},
    {"company_name": "FutureTech Dynamics", "employee_name": "Georgia Wilson", "position": "Engineering Lead"},
    {"company_name": "FutureTech Dynamics", "employee_name": "Henry Miller", "position": "Office Manager"},
    {"company_name": "FutureTech Dynamics", "employee_name": "Isla Taylor", "position": "Data Engineer"},
    {"company_name": "NextGen Innovations", "employee_name": "Jackie Lopez", "position": "Software Architect"},
    {"company_name": "NextGen Innovations", "employee_name": "Kieran Moore", "position": "Customer Support Lead"},
    {"company_name": "NextGen Innovations", "employee_name": "Lydia Martinez", "position": "Financial Advisor"},
    {"company_name": "NextGen Innovations", "employee_name": "Mason Allen", "position": "HR Specialist"},
    {"company_name": "NextGen Innovations", "employee_name": "Nina Wright", "position": "Lead Developer"},
    {"company_name": "Synergy Corp", "employee_name": "Oscar Davis", "position": "Operations Manager"},
    {"company_name": "Synergy Corp", "employee_name": "Peyton Reed", "position": "E-commerce Specialist"},
    {"company_name": "Synergy Corp", "employee_name": "Quinn Baker", "position": "Technical Support"},
    {"company_name": "Synergy Corp", "employee_name": "Riley Collins", "position": "Business Development Manager"},
    {"company_name": "Synergy Corp", "employee_name": "Samantha James", "position": "Database Administrator"},
    {"company_name": "Zenith Group", "employee_name": "Travis Green", "position": "Product Marketing Manager"},
    {"company_name": "Zenith Group", "employee_name": "Uma Rodriguez", "position": "Software Development Manager"},
    {"company_name": "Zenith Group", "employee_name": "Vince Stewart", "position": "Creative Director"},
    {"company_name": "Zenith Group", "employee_name": "Wendy Hughes", "position": "UI/UX Designer"},
    {"company_name": "Zenith Group", "employee_name": "Xander Phillips", "position": "Project Manager"}
]

# %%
cd=pd.DataFrame(employees)

# %%
cd
# Out:
#              company_name    employee_name                      position
# 0    Tech Innovators Inc.    Alice Johnson             Software Engineer
# 1    Tech Innovators Inc.        Bob Smith                Data Scientist
# 2    Tech Innovators Inc.      Carol White               Product Manager
# 3    Tech Innovators Inc.      David Brown                   UX Designer
# 4    Tech Innovators Inc.        Eva Davis          Marketing Specialist
# 5   Global Solutions Ltd.      Frank Moore                    HR Manager
# 6   Global Solutions Ltd.        Grace Lee               Sales Executive
# 7   Global Solutions Ltd.      Hank Wilson             Financial Analyst
# 8   Global Solutions Ltd.       Ivy Taylor              Customer Support
# 9   Global Solutions Ltd.      Jack Harris         Systems Administrator
# 10      Bright Future Co.   Kelly Martinez              Product Designer
# 11      Bright Future Co.       Liam Clark                  Data Analyst
# ...

# %%
cd.drop_duplicates(subset=['company_name'],keep='first')
# Out:
#              company_name   employee_name                   position
# 0    Tech Innovators Inc.   Alice Johnson          Software Engineer
# 5   Global Solutions Ltd.     Frank Moore                 HR Manager
# 10      Bright Future Co.  Kelly Martinez           Product Designer
# 15     Visionary Tech LLC       Paul King           Graphic Designer
# 20    Pioneer Enterprises      Uma Cooper         Software Developer
# 25    InnovateX Solutions      Zane Allen           Business Analyst
# 30    FutureTech Dynamics  Eleanor Brooks              UX Researcher
# 35    NextGen Innovations    Jackie Lopez         Software Architect
# 40           Synergy Corp     Oscar Davis         Operations Manager
# 45           Zenith Group    Travis Green  Product Marketing Manager

# %%
cd.drop_duplicates(subset=['company_name'],keep='last')
# Out:
#              company_name    employee_name                position
# 4    Tech Innovators Inc.        Eva Davis    Marketing Specialist
# 9   Global Solutions Ltd.      Jack Harris   Systems Administrator
# 14      Bright Future Co.     Olivia Young           Web Developer
# 19     Visionary Tech LLC       Tina Baker         Product Manager
# 24    Pioneer Enterprises       Yara Moore        Network Engineer
# 29    InnovateX Solutions        Derek Lee        Technical Writer
# 34    FutureTech Dynamics      Isla Taylor           Data Engineer
# 39    NextGen Innovations      Nina Wright          Lead Developer
# 44           Synergy Corp   Samantha James  Database Administrator
# 49           Zenith Group  Xander Phillips         Project Manager

# %%
cd.to_csv('/content/drive/My Drive/company data.csv', index=False)

# %% [markdown]
# xled and openpyxl are the libraries to handel excel files in panda

# %%
com_dat = pd.read_csv('/content/drive/My Drive/company data.csv')

# %%
com_dat
# Out:
#              company_name    employee_name                      position
# 0    Tech Innovators Inc.    Alice Johnson             Software Engineer
# 1    Tech Innovators Inc.        Bob Smith                Data Scientist
# 2    Tech Innovators Inc.      Carol White               Product Manager
# 3    Tech Innovators Inc.      David Brown                   UX Designer
# 4    Tech Innovators Inc.        Eva Davis          Marketing Specialist
# 5   Global Solutions Ltd.      Frank Moore                    HR Manager
# 6   Global Solutions Ltd.        Grace Lee               Sales Executive
# 7   Global Solutions Ltd.      Hank Wilson             Financial Analyst
# 8   Global Solutions Ltd.       Ivy Taylor              Customer Support
# 9   Global Solutions Ltd.      Jack Harris         Systems Administrator
# 10      Bright Future Co.   Kelly Martinez              Product Designer
# 11      Bright Future Co.       Liam Clark                  Data Analyst
# ...

# %%
com_dat.drop(2,axis=0,inplace=True)

# %%
com_dat
# Out:
#              company_name    employee_name                      position
# 0    Tech Innovators Inc.    Alice Johnson             Software Engineer
# 1    Tech Innovators Inc.        Bob Smith                Data Scientist
# 3    Tech Innovators Inc.      David Brown                   UX Designer
# 4    Tech Innovators Inc.        Eva Davis          Marketing Specialist
# 6   Global Solutions Ltd.        Grace Lee               Sales Executive
# 8   Global Solutions Ltd.       Ivy Taylor              Customer Support
# 9   Global Solutions Ltd.      Jack Harris         Systems Administrator
# 10      Bright Future Co.   Kelly Martinez              Product Designer
# 11      Bright Future Co.       Liam Clark                  Data Analyst
# 12      Bright Future Co.        Mia Lewis          Business Development
# 13      Bright Future Co.      Nate Walker           Project Coordinator
# 14      Bright Future Co.     Olivia Young                 Web Developer
# ...

# %%
com_dat.drop([42,34,5,7],axis=0,inplace=True)

# %%
com_dat
# Out:
#              company_name    employee_name                      position
# 0    Tech Innovators Inc.    Alice Johnson             Software Engineer
# 1    Tech Innovators Inc.        Bob Smith                Data Scientist
# 3    Tech Innovators Inc.      David Brown                   UX Designer
# 4    Tech Innovators Inc.        Eva Davis          Marketing Specialist
# 6   Global Solutions Ltd.        Grace Lee               Sales Executive
# 8   Global Solutions Ltd.       Ivy Taylor              Customer Support
# 9   Global Solutions Ltd.      Jack Harris         Systems Administrator
# 10      Bright Future Co.   Kelly Martinez              Product Designer
# 11      Bright Future Co.       Liam Clark                  Data Analyst
# 12      Bright Future Co.        Mia Lewis          Business Development
# 13      Bright Future Co.      Nate Walker           Project Coordinator
# 14      Bright Future Co.     Olivia Young                 Web Developer
# ...

# %%
com_dat.drop((i for i in[43,35,6,8]),axis=0,inplace=True)

# %%
com_dat
# Out:
#              company_name    employee_name                      position
# 0    Tech Innovators Inc.    Alice Johnson             Software Engineer
# 1    Tech Innovators Inc.        Bob Smith                Data Scientist
# 3    Tech Innovators Inc.      David Brown                   UX Designer
# 4    Tech Innovators Inc.        Eva Davis          Marketing Specialist
# 9   Global Solutions Ltd.      Jack Harris         Systems Administrator
# 10      Bright Future Co.   Kelly Martinez              Product Designer
# 11      Bright Future Co.       Liam Clark                  Data Analyst
# 12      Bright Future Co.        Mia Lewis          Business Development
# 13      Bright Future Co.      Nate Walker           Project Coordinator
# 14      Bright Future Co.     Olivia Young                 Web Developer
# 15     Visionary Tech LLC        Paul King              Graphic Designer
# 16     Visionary Tech LLC      Quinn Scott             Marketing Manager
# ...

# %%
com_dat.reset_index()
# Out:
#     index           company_name    employee_name  \
# 0       0   Tech Innovators Inc.    Alice Johnson
# 1       1   Tech Innovators Inc.        Bob Smith
# 2       3   Tech Innovators Inc.      David Brown
# 3       4   Tech Innovators Inc.        Eva Davis
# 4       9  Global Solutions Ltd.      Jack Harris
# 5      10      Bright Future Co.   Kelly Martinez
# 6      11      Bright Future Co.       Liam Clark
# 7      12      Bright Future Co.        Mia Lewis
# 8      13      Bright Future Co.      Nate Walker
# 9      14      Bright Future Co.     Olivia Young
# 10     15     Visionary Tech LLC        Paul King
# 11     16     Visionary Tech LLC      Quinn Scott
# 12     17     Visionary Tech LLC     Rachel Adams
# 13     18     Visionary Tech LLC     Steve Nelson
# 14     19     Visionary Tech LLC       Tina Baker
# 15     20    Pioneer Enterprises       Uma Cooper
# 16     21    Pioneer Enterprises    Vera Mitchell
# 17     22    Pioneer Enterprises    Will Robinson
# ...

# %%
com_dat.reset_index(drop=True, inplace=True)

# %%
com_dat
# Out:
#              company_name    employee_name                      position
# 0    Tech Innovators Inc.    Alice Johnson             Software Engineer
# 1    Tech Innovators Inc.        Bob Smith                Data Scientist
# 2    Tech Innovators Inc.      David Brown                   UX Designer
# 3    Tech Innovators Inc.        Eva Davis          Marketing Specialist
# 4   Global Solutions Ltd.      Jack Harris         Systems Administrator
# 5       Bright Future Co.   Kelly Martinez              Product Designer
# 6       Bright Future Co.       Liam Clark                  Data Analyst
# 7       Bright Future Co.        Mia Lewis          Business Development
# 8       Bright Future Co.      Nate Walker           Project Coordinator
# 9       Bright Future Co.     Olivia Young                 Web Developer
# 10     Visionary Tech LLC        Paul King              Graphic Designer
# 11     Visionary Tech LLC      Quinn Scott             Marketing Manager
# ...

# %%
com_dat.to_csv('/content/drive/My Drive/company data.csv', index=False)

# %%
com_dat.to_excel('/content/drive/My Drive/company data.xlsx', index=False)
